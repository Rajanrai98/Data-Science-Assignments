# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sn
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from keras.models import Sequential
from keras.optimizers import Adam
from keras.layers import Dense

# %%
! pip install keras
! pip install tensorflow

# %%
data = pd.read_csv(r"C:\Users\user\Downloads\gas_turbines.csv")

# %%
data
# Out:
#            AT      AP      AH    AFDP    GTEP     TIT     TAT     TEY     CDP  \
# 0      6.8594  1007.9  96.799  3.5000  19.663  1059.2  550.00  114.70  10.605
# 1      6.7850  1008.4  97.118  3.4998  19.728  1059.3  550.00  114.72  10.598
# 2      6.8977  1008.8  95.939  3.4824  19.779  1059.4  549.87  114.71  10.601
# 3      7.0569  1009.2  95.249  3.4805  19.792  1059.6  549.99  114.72  10.606
# 4      7.3978  1009.7  95.150  3.4976  19.765  1059.7  549.98  114.72  10.612
# ...       ...     ...     ...     ...     ...     ...     ...     ...     ...
# 15034  9.0301  1005.6  98.460  3.5421  19.164  1049.7  546.21  111.61  10.400
# 15035  7.8879  1005.9  99.093  3.5059  19.414  1046.3  543.22  111.78  10.433
# 15036  7.2647  1006.3  99.496  3.4770  19.530  1037.7  537.32  110.19  10.483
# 15037  7.0060  1006.8  99.008  3.4486  19.377  1043.2  541.24  110.74  10.533
# 15038  6.9279  1007.2  97.533  3.4275  19.306  1049.9  545.85  111.58  10.583
#
#            CO     NOX
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15039 entries, 0 to 15038
# Data columns (total 11 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   AT      15039 non-null  float64
#  1   AP      15039 non-null  float64
#  2   AH      15039 non-null  float64
#  3   AFDP    15039 non-null  float64
#  4   GTEP    15039 non-null  float64
#  5   TIT     15039 non-null  float64
#  6   TAT     15039 non-null  float64
#  7   TEY     15039 non-null  float64
#  8   CDP     15039 non-null  float64
#  9   CO      15039 non-null  float64
#  10  NOX     15039 non-null  float64
# dtypes: float64(11)
# memory usage: 1.3 MB

# %%
data.describe()
# Out:
#                  AT           AP            AH          AFDP          GTEP  \
# count  15039.000000  15039.00000  15039.000000  15039.000000  15039.000000
# mean      17.764381   1013.19924     79.124174      4.200294     25.419061
# std        7.574323      6.41076     13.793439      0.760197      4.173916
# min        0.522300    985.85000     30.344000      2.087400     17.878000
# 25%       11.408000   1008.90000     69.750000      3.723900     23.294000
# 50%       18.186000   1012.80000     82.266000      4.186200     25.082000
# 75%       23.862500   1016.90000     90.043500      4.550900     27.184000
# max       34.929000   1034.20000    100.200000      7.610600     37.402000
#
#                 TIT           TAT           TEY           CDP            CO  \
# count  15039.000000  15039.000000  15039.000000  15039.000000  15039.000000
# mean    1083.798770    545.396183    134.188464     12.102353      1.972499
# ...

# %%
data.corr()
# Out:
#             AT        AP        AH      AFDP      GTEP       TIT       TAT  \
# AT    1.000000 -0.412953 -0.549432 -0.099333 -0.049103  0.093067  0.338569
# AP   -0.412953  1.000000  0.042573  0.040318  0.078575  0.029650 -0.223479
# AH   -0.549432  0.042573  1.000000 -0.119249 -0.202784 -0.247781  0.010859
# AFDP -0.099333  0.040318 -0.119249  1.000000  0.744251  0.627254 -0.571541
# GTEP -0.049103  0.078575 -0.202784  0.744251  1.000000  0.874526 -0.756884
# TIT   0.093067  0.029650 -0.247781  0.627254  0.874526  1.000000 -0.357320
# TAT   0.338569 -0.223479  0.010859 -0.571541 -0.756884 -0.357320  1.000000
# TEY  -0.207495  0.146939 -0.110272  0.717995  0.977042  0.891587 -0.720356
# CDP  -0.100705  0.131198 -0.182010  0.727152  0.993784  0.887238 -0.744740
# CO   -0.088588  0.041614  0.165505 -0.334207 -0.508259 -0.688272  0.063404
# NOX  -0.600006  0.256744  0.143061 -0.037299 -0.208496 -0.231636  0.009888
#
#            TEY       CDP        CO       NOX
# ...

# %%
data.head(5)
# Out:
#        AT      AP      AH    AFDP    GTEP     TIT     TAT     TEY     CDP  \
# 0  6.8594  1007.9  96.799  3.5000  19.663  1059.2  550.00  114.70  10.605
# 1  6.7850  1008.4  97.118  3.4998  19.728  1059.3  550.00  114.72  10.598
# 2  6.8977  1008.8  95.939  3.4824  19.779  1059.4  549.87  114.71  10.601
# 3  7.0569  1009.2  95.249  3.4805  19.792  1059.6  549.99  114.72  10.606
# 4  7.3978  1009.7  95.150  3.4976  19.765  1059.7  549.98  114.72  10.612
#
#        CO     NOX
# 0  3.1547  82.722
# 1  3.2363  82.776
# 2  3.2012  82.468
# 3  3.1923  82.670
# 4  3.2484  82.311

# %%
data.isnull().sum()
# Out:
# AT      0
# AP      0
# AH      0
# AFDP    0
# GTEP    0
# TIT     0
# TAT     0
# TEY     0
# CDP     0
# CO      0
# NOX     0
# dtype: int64

# %%
data.duplicated().any()
# Out:
# False

# %%
data.tail(5)
# Out:
#            AT      AP      AH    AFDP    GTEP     TIT     TAT     TEY     CDP  \
# 15034  9.0301  1005.6  98.460  3.5421  19.164  1049.7  546.21  111.61  10.400
# 15035  7.8879  1005.9  99.093  3.5059  19.414  1046.3  543.22  111.78  10.433
# 15036  7.2647  1006.3  99.496  3.4770  19.530  1037.7  537.32  110.19  10.483
# 15037  7.0060  1006.8  99.008  3.4486  19.377  1043.2  541.24  110.74  10.533
# 15038  6.9279  1007.2  97.533  3.4275  19.306  1049.9  545.85  111.58  10.583
#
#            CO     NOX
# 15034  4.5186  79.559
# 15035  4.8470  79.917
# 15036  7.9632  90.912
# 15037  6.2494  93.227
# 15038  4.9816  92.498

# %% [markdown]
# ## Boxplot

# %%
sn.boxplot(data['TEY'] , color = 'red')
# Out:
# <Axes: >

# %%
sn.boxplot(data['AT'] , color =  'red')
# Out:
# <Axes: >

# %%
plt.boxplot(data['TEY'] )
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1d6cc3d4760>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1d6cc3d4ca0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1d6cc361b40>],
#  'medians': [<matplotlib.lines.Line2D at 0x1d6cc3d51e0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1d6cc3d5480>],
#  'means': []}

# %%
sn.histplot(data['TEY'] , color = 'blue')
# Out:
# <Axes: xlabel='TEY', ylabel='Count'>

# %%
sn.distplot(data['TEY'] , color = 'red')
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_18104\3246010992.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(data['TEY'] , color = 'red')
# <Axes: xlabel='TEY', ylabel='Density'>

# %%
data.head(5)
# Out:
#        AT      AP      AH    AFDP    GTEP     TIT     TAT     TEY     CDP  \
# 0  6.8594  1007.9  96.799  3.5000  19.663  1059.2  550.00  114.70  10.605
# 1  6.7850  1008.4  97.118  3.4998  19.728  1059.3  550.00  114.72  10.598
# 2  6.8977  1008.8  95.939  3.4824  19.779  1059.4  549.87  114.71  10.601
# 3  7.0569  1009.2  95.249  3.4805  19.792  1059.6  549.99  114.72  10.606
# 4  7.3978  1009.7  95.150  3.4976  19.765  1059.7  549.98  114.72  10.612
#
#        CO     NOX
# 0  3.1547  82.722
# 1  3.2363  82.776
# 2  3.2012  82.468
# 3  3.1923  82.670
# 4  3.2484  82.311

# %%
x = data.loc[: , ['AT','AP','AH','AFDP','GTEP','TIT','TAT','CDP','CO','NOX']]

# %%
y =  data.loc[: , ['TEY']]

# %%
x.head(5)
# Out:
#        AT      AP      AH    AFDP    GTEP     TIT     TAT     CDP      CO  \
# 0  6.8594  1007.9  96.799  3.5000  19.663  1059.2  550.00  10.605  3.1547
# 1  6.7850  1008.4  97.118  3.4998  19.728  1059.3  550.00  10.598  3.2363
# 2  6.8977  1008.8  95.939  3.4824  19.779  1059.4  549.87  10.601  3.2012
# 3  7.0569  1009.2  95.249  3.4805  19.792  1059.6  549.99  10.606  3.1923
# 4  7.3978  1009.7  95.150  3.4976  19.765  1059.7  549.98  10.612  3.2484
#
#       NOX
# 0  82.722
# 1  82.776
# 2  82.468
# 3  82.670
# 4  82.311

# %%
x_train , x_test , y_train , y_test = train_test_split(x , y , test_size = 0.20 , random_state = 42)

# %%
scaler = StandardScaler()

x_train_scaled = scaler.fit_transform(x_train)

x_test_scaled = scaler.transform(x_test)

# %% [markdown]
# ## Build a Neural Network

# %%
model = Sequential()
model.add(Dense(10 , activation = 'relu' , input_shape = (x_train.shape[1],)))
model.add(Dense(1))
model.compile(optimizer = 'Adam' , loss = 'mean_squared_error')

# %%
MD = model.fit(x_train_scaled , y_train , epochs = 20 , batch_size = 5 , validation_split = 0.20)
# Out:
# Epoch 1/20
# 1925/1925 [==============================] - 5s 2ms/step - loss: 12907.5967 - val_loss: 5532.8315
# Epoch 2/20
# 1925/1925 [==============================] - 4s 2ms/step - loss: 1799.6080 - val_loss: 369.3498
# Epoch 3/20
# 1925/1925 [==============================] - 5s 2ms/step - loss: 259.7055 - val_loss: 211.4332
# Epoch 4/20
# 1925/1925 [==============================] - 4s 2ms/step - loss: 154.5673 - val_loss: 123.9041
# Epoch 5/20
# 1925/1925 [==============================] - 4s 2ms/step - loss: 90.8081 - val_loss: 73.4817
# Epoch 6/20
# 1925/1925 [==============================] - 4s 2ms/step - loss: 54.8856 - val_loss: 45.0392
# Epoch 7/20
# 1925/1925 [==============================] - 5s 2ms/step - loss: 32.5258 - val_loss: 25.4622
# Epoch 8/20
# 1925/1925 [==============================] - 3s 2ms/step - loss: 18.8319 - val_loss: 13.9563
# Epoch 9/20
# 1925/1925 [==============================] - 4s 2ms/step - loss: 11.6071 - val_loss: 9.3635
# Epoch 10/20
# ...

# %%
## Evaluate the model performance 

loss = model.evaluate(x_test_scaled , y_test)
# Out:
# 94/94 [==============================] - 0s 3ms/step - loss: 0.5133

# %%
loss
# Out:
# 0.5133007764816284

# %%
y_pred = model.predict_on_batch(x_test_scaled)

# %%
y_pred
# Out:
# array([[134.7951  ],
#        [112.289604],
#        [134.37782 ],
#        ...,
#        [146.12062 ],
#        [149.85071 ],
#        [111.61916 ]], dtype=float32)

# %%
## plot scatter plot between y_pred , y_test

# %%
plt.scatter(y_pred  , y_test)
