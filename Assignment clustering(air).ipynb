# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import AgglomerativeClustering , KMeans , DBSCAN
from scipy.cluster.hierarchy import linkage,dendrogram

# %%
data = pd.read_excel(r"C:\Users\user\Downloads\EastWestAirline .1.xlsx")

# %%
data
# Out:
#        ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0        1    28143           0          1          1          1          174
# 1        2    19244           0          1          1          1          215
# 2        3    41354           0          1          1          1         4123
# 3        4    14776           0          1          1          1          500
# 4        5    97752           0          4          1          1        43300
# ...    ...      ...         ...        ...        ...        ...          ...
# 3994  4017    18476           0          1          1          1         8525
# 3995  4018    64385           0          1          1          1          981
# 3996  4019    73597           0          3          1          1        25447
# 3997  4020    54899           0          1          1          1          500
# 3998  4021     3016           0          1          1          1            0
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3999 entries, 0 to 3998
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ID#                3999 non-null   int64
#  1   Balance            3999 non-null   int64
#  2   Qual_miles         3999 non-null   int64
#  3   cc1_miles          3999 non-null   int64
#  4   cc2_miles          3999 non-null   int64
#  5   cc3_miles          3999 non-null   int64
#  6   Bonus_miles        3999 non-null   int64
#  7   Bonus_trans        3999 non-null   int64
#  8   Flight_miles_12mo  3999 non-null   int64
#  9   Flight_trans_12    3999 non-null   int64
#  10  Days_since_enroll  3999 non-null   int64
#  11  Award?             3999 non-null   int64
# dtypes: int64(12)
# memory usage: 375.0 KB

# %%
data.shape
# Out:
# (3999, 12)

# %%
data.isnull().sum()
# Out:
# ID#                  0
# Balance              0
# Qual_miles           0
# cc1_miles            0
# cc2_miles            0
# cc3_miles            0
# Bonus_miles          0
# Bonus_trans          0
# Flight_miles_12mo    0
# Flight_trans_12      0
# Days_since_enroll    0
# Award?               0
# dtype: int64

# %%
data.head()
# Out:
#    ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0    1    28143           0          1          1          1          174
# 1    2    19244           0          1          1          1          215
# 2    3    41354           0          1          1          1         4123
# 3    4    14776           0          1          1          1          500
# 4    5    97752           0          4          1          1        43300
#
#    Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  Award?
# 0            1                  0                0               7000       0
# 1            2                  0                0               6968       0
# 2            4                  0                0               7034       0
# 3            1                  0                0               6952       0
# 4           26               2077                4               6935       1

# %%
df = data.drop(['ID#'] , axis = 1)

# %%
df
# Out:
#       Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0       28143           0          1          1          1          174
# 1       19244           0          1          1          1          215
# 2       41354           0          1          1          1         4123
# 3       14776           0          1          1          1          500
# 4       97752           0          4          1          1        43300
# ...       ...         ...        ...        ...        ...          ...
# 3994    18476           0          1          1          1         8525
# 3995    64385           0          1          1          1          981
# 3996    73597           0          3          1          1        25447
# 3997    54899           0          1          1          1          500
# 3998     3016           0          1          1          1            0
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %%
## Normalization of datasets

scaler = StandardScaler()
x = scaler.fit_transform(df)

# %%
x
# Out:
# array([[-4.51140783e-01, -1.86298687e-01, -7.69578406e-01, ...,
#         -3.62167870e-01,  1.39545434e+00, -7.66919299e-01],
#        [-5.39456874e-01, -1.86298687e-01, -7.69578406e-01, ...,
#         -3.62167870e-01,  1.37995704e+00, -7.66919299e-01],
#        [-3.20031232e-01, -1.86298687e-01, -7.69578406e-01, ...,
#         -3.62167870e-01,  1.41192021e+00, -7.66919299e-01],
#        ...,
#        [-4.29480975e-05, -1.86298687e-01,  6.83121167e-01, ...,
#         -3.62167870e-01, -1.31560393e+00,  1.30391816e+00],
#        [-1.85606976e-01, -1.86298687e-01, -7.69578406e-01, ...,
#         -9.85033311e-02, -1.31608822e+00, -7.66919299e-01],
#        [-7.00507951e-01, -1.86298687e-01, -7.69578406e-01, ...,
#         -3.62167870e-01, -1.31754109e+00, -7.66919299e-01]])

# %%
pd.DataFrame(x)
# Out:
#             0         1         2         3         4         5         6   \
# 0    -0.451141 -0.186299 -0.769578 -0.098242 -0.062767 -0.702786 -1.104065
# 1    -0.539457 -0.186299 -0.769578 -0.098242 -0.062767 -0.701088 -0.999926
# 2    -0.320031 -0.186299 -0.769578 -0.098242 -0.062767 -0.539253 -0.791649
# 3    -0.583799 -0.186299 -0.769578 -0.098242 -0.062767 -0.689286 -1.104065
# 4     0.239678 -0.186299  1.409471 -0.098242 -0.062767  1.083121  1.499394
# ...        ...       ...       ...       ...       ...       ...       ...
# 3994 -0.547079 -0.186299 -0.769578 -0.098242 -0.062767 -0.356960 -0.791649
# 3995 -0.091465 -0.186299 -0.769578 -0.098242 -0.062767 -0.669367 -0.687511
# 3996 -0.000043 -0.186299  0.683121 -0.098242 -0.062767  0.343804 -0.375096
# 3997 -0.185607 -0.186299 -0.769578 -0.098242 -0.062767 -0.689286 -1.104065
# 3998 -0.700508 -0.186299 -0.769578 -0.098242 -0.062767 -0.709992 -1.208203
#
#             7         8         9         10
# ...

# %%
## hierarchical Clustering

hc = AgglomerativeClustering(n_clusters = 3 , linkage = 'ward')
hc.fit(x)
hlabels = hc.labels_

# %%
hlabels
# Out:
# array([0, 0, 0, ..., 1, 0, 0], dtype=int64)

# %%
pd.DataFrame(hc.labels_)
# Out:
#       0
# 0     0
# 1     0
# 2     0
# 3     0
# 4     1
# ...  ..
# 3994  0
# 3995  0
# 3996  1
# 3997  0
# 3998  0
#
# [3999 rows x 1 columns]

# %%
hc_cluster = pd.DataFrame(hlabels, columns = ['hc_cluster'])

# %%
hc_cluster.head()
# Out:
#    hc_cluster
# 0           0
# 1           0
# 2           0
# 3           0
# 4           1

# %%
pd.concat([df , hc_cluster] , axis = 1).head()
# Out:
#    Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0    28143           0          1          1          1          174
# 1    19244           0          1          1          1          215
# 2    41354           0          1          1          1         4123
# 3    14776           0          1          1          1          500
# 4    97752           0          4          1          1        43300
#
#    Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  Award?  \
# 0            1                  0                0               7000       0
# 1            2                  0                0               6968       0
# 2            4                  0                0               7034       0
# 3            1                  0                0               6952       0
# 4           26               2077                4               6935       1
#
#    hc_cluster
# 0           0
# 1           0
# 2           0
# 3           0
# ...

# %%
z = linkage(df , method = 'ward')
plt.figure(figsize=(10,5))
dendrogram(z)
plt.xlabel('Data point')
plt.ylabel('Distance')
plt.title('Dendrogram')
plt.show()

# %%
## Kmean clustering

kmean = KMeans(n_clusters = 3 , random_state = 42)
kmean.fit(x)
kmeanlabel = kmean.labels_
# Out:
# C:\Users\user\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
kmeanlabel
# Out:
# array([2, 2, 2, ..., 0, 2, 2])

# %%
k_cluster = pd.DataFrame(kmeanlabel , columns = ['k_cluster'])

# %%
k_cluster.head()
# Out:
#    k_cluster
# 0          2
# 1          2
# 2          2
# 3          2
# 4          0

# %%
pd.concat([df , k_cluster] , axis = 1)
# Out:
#       Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0       28143           0          1          1          1          174
# 1       19244           0          1          1          1          215
# 2       41354           0          1          1          1         4123
# 3       14776           0          1          1          1          500
# 4       97752           0          4          1          1        43300
# ...       ...         ...        ...        ...        ...          ...
# 3994    18476           0          1          1          1         8525
# 3995    64385           0          1          1          1          981
# 3996    73597           0          3          1          1        25447
# 3997    54899           0          1          1          1          500
# 3998     3016           0          1          1          1            0
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %%
## to find the optimum number of cluster by using elbow method
wcss = []
for k in range(1 , 12):
    kmeans = KMeans(n_clusters = k , init = 'k-means++' , random_state = 42)
    kmeans.fit(x)
    wcss.append(kmeans.inertia_)
# Out:
# C:\Users\user\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\user\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\user\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\user\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# ...

# %%
wcss
# Out:
# [43989.0,
#  35409.51662986131,
#  30899.216408790584,
#  27162.16610612414,
#  23707.163884815618,
#  21089.756870023866,
#  19166.389043789353,
#  17316.725861419516,
#  15960.406001471114,
#  14732.229882347436,
#  13706.437043029613]

# %%
number_cluster = range(1 , 12)
plt.plot(number_cluster , wcss)
plt.title('elbow method')
plt.xlabel('number of cluster')
plt.ylabel('within-cluster sum of squares')
# Out:
# Text(0, 0.5, 'within-cluster sum of squares')

# %%
## perform DBSCAN CLUSTERING

dbscan = DBSCAN(eps = 0.5 , min_samples = 5)
dbscan.fit(x)
dlabels = dbscan.labels_

# %%
dlabels
# Out:
# array([ 0,  0,  0, ..., -1,  0,  0], dtype=int64)

# %%
cluster =  pd.DataFrame(dbscan.labels_ , columns = ['cluster'])

# %%
cluster.head()
# Out:
#    cluster
# 0        0
# 1        0
# 2        0
# 3        0
# 4       -1

# %%
pd.concat([df , cluster] , axis = 1)
# Out:
#       Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0       28143           0          1          1          1          174
# 1       19244           0          1          1          1          215
# 2       41354           0          1          1          1         4123
# 3       14776           0          1          1          1          500
# 4       97752           0          4          1          1        43300
# ...       ...         ...        ...        ...        ...          ...
# 3994    18476           0          1          1          1         8525
# 3995    64385           0          1          1          1          981
# 3996    73597           0          3          1          1        25447
# 3997    54899           0          1          1          1          500
# 3998     3016           0          1          1          1            0
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %%
## Visualization of clusters

plt.scatter(df['Balance'],df['Bonus_miles']) 
        
plt.xlabel('Balance')
plt.ylabel('Bonus Miles')
plt.show()

# %%
## Distribution of data sets
import seaborn as sn

# %%
sn.distplot(data['Balance'] , color = 'red')
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_21216\4072019854.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(data['Balance'] , color = 'red')
# <Axes: xlabel='Balance', ylabel='Density'>

# %%
plt.boxplot(df['Balance'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2a49ad740d0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2a49ad74640>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2a49ad6fee0>],
#  'medians': [<matplotlib.lines.Line2D at 0x2a49ad74b80>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2a49ad74e20>],
#  'means': []}

# %%
sn.histplot(data['Balance'] , color = 'red')
# Out:
# <Axes: xlabel='Balance', ylabel='Count'>
